# %%
import pandas as pd
df = pd.read_csv('sales_data_with_issues.csv');
print(df.head());
# Out:
#    TransactionID        Date CustomerID   CustomerName   Product     Category  \
# 0           1001  2024-01-05       C001  Alice Johnson  Keyboard  Electronics
# 1           1002  2024-01-06       C002      Bob Smith     Mouse  Electronics
# 2           1003  2024-01-06       C003    Carol White  Notebook   Stationery
# 3           1004  2024-01-07       C004    David Brown    Pencil   Stationery
# 4           1005  2024-01-08       C001  Alice Johnson   Monitor  Electronics
#
#    Quantity  Price  Total           City State PaymentMethod  Discount
# 0         2   25.0   50.0       New York    NY   Credit Card         5
# 1         1   15.0   15.0         Boston    MA    Debit Card         0
# 2         3    5.0   15.0  San Francisco    CA          Cash         2
# 3        10    0.5    5.0         Austin    TX   Credit Card         0
# 4         1  120.0  120.0       New York    NY   Credit Card        10

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  22 non-null     int64
#  1   Date           22 non-null     object
#  2   CustomerID     22 non-null     object
#  3   CustomerName   22 non-null     object
#  4   Product        22 non-null     object
#  5   Category       22 non-null     object
#  6   Quantity       22 non-null     int64
#  7   Price          22 non-null     float64
#  8   Total          22 non-null     float64
#  9   City           22 non-null     object
#  10  State          22 non-null     object
#  11  PaymentMethod  22 non-null     object
#  12  Discount       22 non-null     int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 2.4+ KB

# %%
print(df.isnull().sum());
# Out:
# TransactionID    0
# Date             0
# CustomerID       0
# CustomerName     0
# Product          0
# Category         0
# Quantity         0
# Price            0
# Total            0
# City             0
# State            0
# PaymentMethod    0
# Discount         0
# dtype: int64

# %%
print(df.duplicated().sum());
# Out:
# 14

# %%
df = df.drop_duplicates();

# %%
import pandas as pd
df = pd.read_csv('sales_data_with_issues.csv');
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  22 non-null     int64
#  1   Date           22 non-null     object
#  2   CustomerID     22 non-null     object
#  3   CustomerName   22 non-null     object
#  4   Product        22 non-null     object
#  5   Category       22 non-null     object
#  6   Quantity       22 non-null     int64
#  7   Price          22 non-null     float64
#  8   Total          22 non-null     float64
#  9   City           22 non-null     object
#  10  State          22 non-null     object
#  11  PaymentMethod  22 non-null     object
#  12  Discount       22 non-null     int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 2.4+ KB

# %%
print(df.duplicated().sum())  ##finding the number of duplicated rows
# Out:
# 1

# %%
df = df.drop_duplicates() ## removing the duplicated rows from the dataframes

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 0 to 21
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  21 non-null     int64
#  1   Date           21 non-null     object
#  2   CustomerID     21 non-null     object
#  3   CustomerName   21 non-null     object
#  4   Product        21 non-null     object
#  5   Category       21 non-null     object
#  6   Quantity       21 non-null     int64
#  7   Price          21 non-null     float64
#  8   Total          21 non-null     float64
#  9   City           21 non-null     object
#  10  State          21 non-null     object
#  11  PaymentMethod  21 non-null     object
#  12  Discount       21 non-null     int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 2.3+ KB

# %%
df['Discount'] = df['Discount'].astype(float);  ##changing the datatype of a series/column

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 0 to 21
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  21 non-null     int64
#  1   Date           21 non-null     object
#  2   CustomerID     21 non-null     object
#  3   CustomerName   21 non-null     object
#  4   Product        21 non-null     object
#  5   Category       21 non-null     object
#  6   Quantity       21 non-null     int64
#  7   Price          21 non-null     float64
#  8   Total          21 non-null     float64
#  9   City           21 non-null     object
#  10  State          21 non-null     object
#  11  PaymentMethod  21 non-null     object
#  12  Discount       21 non-null     float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 2.3+ KB

# %%
df = df[df['Discount'] >= 100 ];

# %%
discount = df['Discount']
for value in discount:
    print(value);
